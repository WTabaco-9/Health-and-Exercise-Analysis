# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import psycopg as psql

# %% [markdown]
# ## Connecting to the Database

# %%
# Connects to the database
with psql.connect() as db:

    # Creates a cursor to run queries on database
    with db.cursor() as query:
        query.execute("""


        """)

# %% [markdown]
# ## Converting Database to Dataframe for Analysis

# %%
df = pd.read_sql()

# %% [markdown]
# ## Cleaning the Data

# %% [markdown]
# ## Analyzing the Data

# %% [markdown]
# ## Visualization and Storytelling
