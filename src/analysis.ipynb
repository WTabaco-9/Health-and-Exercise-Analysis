# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import psycopg2 as psql

# %% [markdown]
# ## Connecting to the Database

# %%
conn = psql.connect()

cursor = conn.cursor()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 conn = psql.connect(database="C:/Program Files/PostgreSQL/18/data/postgres", user="postgres", password="9WTabaco!", port=5432)
#       3 cursor = conn.cursor()
#
# File c:\Users\winst\AppData\Local\Programs\Python\Python314\Lib\site-packages\psycopg2\__init__.py:135, in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     132     kwasync['async_'] = kwargs.pop('async_')
#     134 dsn = _ext.make_dsn(dsn, **kwargs)
# --> 135 conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     136 if cursor_factory is not None:
#     137     conn.cursor_factory = cursor_factory
#
# OperationalError: connection to server at "localhost" (::1), port 5432 failed: FATAL:  database "C:/Program Files/PostgreSQL/18/data/postgres" does not exist

# %% [markdown]
# ## Converting Database to Dataframe for Analysis

# %%
df = pd.read_sql()

# %% [markdown]
# ## Cleaning the Dataframe

# %% [markdown]
# ## Analyzing the Dataframe

# %% [markdown]
# ## Visualization and Storytelling
